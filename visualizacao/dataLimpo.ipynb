# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

plt.style.use ('default')
sns.set_style('whitegrid')

# %%
df = pd.read_csv ('data_limpo.csv')

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories  Hours_Work  Hours_Sleep
# 0          60    110       130     409.1           0            8
# 1          60    117       145     479.0           8            8
# 2          60    103       135     340.0           7            7
# 3          45    109       175     282.4           0            8
# 4          45    117       148     406.0          10            7
# ..        ...    ...       ...       ...         ...          ...
# 164        60    105       140     290.8           8            7
# 165        60    110       145     300.0           7            8
# 166        60    115       145     310.2           0            8
# 167        75    120       150     320.4           8            7
# 168        75    125       150     330.4          10            8
#
# [169 rows x 6 columns]

# %%
fig, axes = plt.subplots (2, 3, figsize= (15,10))
axes[0 ,0].hist(df['Duration'], bins=15, color='skyblue', edgecolor='black', alpha = 0.7)
# axes[0, 0].hist(df['Duration'], bins=15, colors='skyblue', edgecolor ='black', alpha =0.7)
axes[0,0].set_xlabel('duration (min)')
axes[0,0].set_ylabel('frequencia')
axes[0, 0].set_title('freq')
# Out:
# Text(0.5, 1.0, 'freq')
